# %%
#binary tree

class Node:
    data = None
    leftChild = None
    rightChild = None
    def __init__ (self, val):
        self.data = val
    
class Tree:
    
    root = None
    
    def __init__ (self,root):
        self.q=[]
        self.root=root
        self.q.insert(0,root)
        
        self.stack = []
        self.stack.append(root)
        
        self.stackRoots=[]
        self.stackRoots.append(root)
    
    
    def BreathFirstSearch(self,val):
        if self.q == []:
            return False
        tmp = self.q.pop()
        print(tmp.data)
        if tmp.data == val:
            return True
        if tmp.leftChild!=None:
            self.q.insert(0,tmp.leftChild)
        if tmp.rightChild!=None:
            self.q.insert(0,tmp.rightChild)  
        return self.BreathFirstSearch(val)
        
        
        
    def DepthFirstSearch(self,tmp,val):
        
        tmp = self.stackRoots.pop() 
        nextroot=self.stackRoots(tmp)
        if tmp.leftChild!= None:
            self.stack.append(tmp.leftChild)
        if tmp.rightChild != None:
            self.stack.append(tmp.rightChild)
            
        DepthFirstSearch(nextroot)
        
        
        
        
        
        return
        
    def BestFirstSearch(self,val):
        return
        
    def DjikstraSearch(self,val):
        return
        
    def ConvertToBinarySearchTree(self):
        return
        
    def InOrderTravel(self,tmp):        
        
        if tmp:
            self.InOrderTravel(tmp.leftChild)
            print(tmp.data)
            self.InOrderTravel(tmp.rightChild)
        
    def PreOrderTravel(self,tmp):
        if tmp:
            print(tmp.data)
            self.PreOrderTravel(tmp.leftChild)            
            self.PreOrderTravel(tmp.rightChild)
    
    def PostOrderTravel(self,tmp):
        if tmp:
            self.PostOrderTravel(tmp.leftChild)
            self.PostOrderTravel(tmp.rightChild)
            print(tmp.data)

# %%
node1 = Node(1)
node2 = Node(2)
node3 = Node(3)
node4 = Node(4)
node5 = Node(5)
node6 = Node(6)
node7 = Node(7)

node1.leftChild = node2
node1.rightChild = node3
node2.leftChild = node4
node2.rightChild = node5
node3.leftChild = node6
node3.rightChild = node7

tr = Tree(node1)
print(tr.BreathFirstSearch(9))

tr.InOrderTravel(node1)

tr.PreOrderTravel(node1)
tr.PostOrderTravel(node1)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# False
# 4
# 2
# 5
# 1
# 6
# 3
# 7
# 1
# 2
# 4
# 5
# 3
# 6
# 7
# 4
# 5
# 2
# 6
# 7
# 3
# 1
